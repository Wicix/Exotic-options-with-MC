# %%
from Asset import *
from CalibrateParameters import *
import matplotlib.pyplot as plt

# %%
a = Asset(100, params1['Mu_1'], params1['Sigma_1']) # S0, mu, sigma
b = Asset(100, params1['Mu_2'], params1['Sigma_2'])
rho = params1['rho']
ca = CorrAssets(a, b, rho)

# %%
ca.gen_traj(365,1)
ax = plt.subplot()
ax.plot(np.cumsum(ca.YearFraction), ca.GBM1)
ax.plot(np.cumsum(ca.YearFraction), ca.GBM2)
ax.grid()
plt.show()
