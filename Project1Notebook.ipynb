# %%
from Asset import *
import matplotlib.pyplot as plt

# %%
a = Asset(100, 0.03, 0.3) # S0, mu, sigma
b = Asset(100, 0.03, 0.1)
rho = 0.9
ca = CorrAssets(a, b, rho)

# %%
ca.gen_traj(1000,1)
ax = plt.subplot()
ax.plot(np.cumsum(ca.YearFraction), ca.GBM1)
ax.plot(np.cumsum(ca.YearFraction), ca.GBM2)
ax.grid()
plt.show()
